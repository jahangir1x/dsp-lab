# %% [markdown]
# # DFT for book example

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import firwin, lfilter

# Sampling parameters
fs = 1000  # Sampling frequency (Hz)
t = np.arange(0, 1, 1 / fs)  # Time vector from 0 to 1 second

# Generate the input signal x(t)
x = np.sin(2 * np.pi * 50 * t) + 0.5 * np.sin(2 * np.pi * 200 * t)

# Design FIR filter
cutoff_freq = 100  # Cutoff frequency for the filter (Hz), below the 200 Hz component
num_taps = 101  # Number of filter taps (filter order + 1)
fir_coeff = firwin(num_taps, cutoff_freq / (fs / 2), window="hamming")

# Apply the FIR filter to the signal
filtered_signal = lfilter(fir_coeff, 1.0, x)

# Plot the original and filtered signals
plt.figure(figsize=(14, 6))

# Original signal
plt.subplot(2, 1, 1)
plt.plot(t, x, label="Original Signal")
plt.title("Original Signal with 50 Hz and 200 Hz Components")
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)

# Filtered signal
plt.subplot(2, 1, 2)
plt.plot(t, filtered_signal, color="orange", label="Filtered Signal (50 Hz component)")
plt.title("Filtered Signal (Low-Pass FIR Filter)")
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
